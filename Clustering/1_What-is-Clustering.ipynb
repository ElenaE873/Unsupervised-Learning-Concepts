# %% [markdown]
# ### Clustering

# %% [markdown]
# - the process of grouping items with similar characteristics
# - some samples in the data are more similar to each other than others in the dataset

# %%
#plotting data for clustering
from matplotlib import pyplot as plt

#define x and y coordinates
x_coordinates = 
y_coordinates = 

plot.scatter(x_coordinate, y_coordinates)

# %% [markdown]
# #### Basics of Cluster Analysis

# %% [markdown]
# ##### what is a cluster?

# %% [markdown]
# - group of items (data points) with similar characteristics

# %% [markdown]
# ##### Clustering Algorithms
# - Hierarchical clustering
# - K-Means Clustering
# - Others such as : DBSCAN, Gaussian Methods

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### a Cluster Center (or Centroid)

# %% [markdown]
# - the mean of the attributes of all datapoints in a cluster
# - this mean includes the mean of the x-coordinates and the mean of the y-coordinates
