# %% [markdown]
# 2 Unsupervised learning techniques for visualization:
# - hierarchical clustering
# - t-SNE: "t-distributed stochastic neighbor embedding"
#     - this creates a 2D map of any dataset, and conveys info about the proximity of the samples to one another

# %% [markdown]
# ### Hiearchical Clustering

# %% [markdown]
# - arranges clusters on a hierarchical design
#
# The Method Argument:
# - how to calculate the proximity of clusters
# - single: based on two closest objects
# - complete: based on two farthest objects
# - average: based on the arithmetic mean of all objects
# - centroid: based on the geometric mean of all objects
# - median: based on the median of all objects
# - ward: based on the sum of squares

# %%
#import the linkage and dendogram functions
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage, dendrogram

#the linkage function perform the hierarchical clustering
mergings = linkage(data, 
                   method='complete')

#passing the output of the linkage function to the dendogram function
dendrogram(mergings,
         labels = label_name,
         leaf_rotation=90,
         leaf_font_size=6)

plt.show()

# %%
#using the Normalizer
#Normalize the movements: normalized_movements
normalized_movements = normalize(movements)

#the linkage: mergings
mergings = linkage(normalized_movements, method='complete')

# %% [markdown]
# #### Dendrograms

# %% [markdown]
# - height on dendrogram **coresponds** with a distance between merging clusters
# - helps in showing progressions as clusters are merged
# - it is a branching diagram that demostrates how the clusters are composed by branching out into its child nodes.

# %% [markdown]
# example, here we an see the distance was 6 when they were merged into a cluster ![image.png](attachment:image.png)

# %% [markdown]
# The distance between two clusters is measured/defined by the "linkage" method

# %% [markdown]
# - "**complete linkage**" is when the distance between clusters is max.

# %% [markdown]
# #### Extracting Cluster Labels using "fcluster()"

# %% [markdown]
# fcluster() arguments:
# - distance_matrix: output of linkage() method
# - num_clusters: number of clusters
# - criterion: how to decide thresholds to form clusters

# %%
#conduct a complete linkage
from scipy.cluster.hierarchy import linkage

#the linkage method computes distances between intermediate clusters
mergings = linkage(data, method='complete')

#fcluster generates clusters and assigns associated cluster labels 
from scipy.cluster.hierarchy import fcluster
labels = fcluster(mergings, 
                  15, #maximum height
                  criterion='distance')

# %%
#plotting the scatterplot using seaborn
from matplotlib import pyplot as plt
import seaborn as sns

sns.scatterplot(x='x_coordinate', y='y_coordinate',
               hue='cluster-labels', data=df)
plt.show()

# %% [markdown]
# ##### How is clustering occuring?
# - 1 - Random cluster center is generated for each of the three clusters
# - 2 - The distance to these cluster centers are computed for each datapoint
# - 3 - Based on the closest distance, each datapoint it is assigned to a cluster
# - 4 - The cluster center is recomputed

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
#aligning cluster labels with categories
import pandas as pd
pairs = pd.DataFrame({'labels': labels, 'varieties': varieties})

# %% [markdown]
# ##### Why visualize clusters?

# %% [markdown]
# - understand and make sense of the clusters formed
# - can serve as an additional step for validation of clusters
# - possible to spot additional trends in your data

# %% [markdown]
# ### t-SNE

# %%
#import libraries
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

#create a TSNE object
model = TSNE(learning_rate=100)

#apply fit method to the samples
transformed = model.fit_transform(samples)
    #simultaneous fits the model and transforms the data
    #does not have a separate fit() / transform() methods

#make a scatter plot of the result
xs = transformed[:, 0]
ys = transformed[:, 1]
plot.scatter(xs, ys, c=categories)
plot.show()

# %% [markdown]
# #### t-SNE learning rate

# %% [markdown]
# - Makes t-SNE more complicated than other learning models
# - this is why clustering modeling should be wisely choosen based on the dataset
