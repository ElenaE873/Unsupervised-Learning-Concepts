# %% [markdown]
# ### t-SNE

# %% [markdown]
# t- Distributed Stochastic Neighbor Embedding or t-SNE

# %% [markdown]
# - powerful technique to visualize high dimensional data using feature extraction

# %% [markdown]
# #### tSNE does not work with numerical data

# %% [markdown]
# Will have to drop the numerical data.

# %%
non_numeric = ['column1', 'column2', 'column3']
df_numeric = df.drop(non_numeric, axis=1)

#check for drop
df_numeric.shape

# %% [markdown]
# One could also use the one-hot encoding approach as well, but might be a simpler approach.

# %%
#import libraries
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

#create a TSNE object
model = TSNE(learning_rate=100)  #learning rates fall in the 10 to 1000 range

#apply fit method to the samples
transformed = model.fit_transform(numeric)
    #simultaneous fits the model and transforms the data
    #does not have a separate fit() / transform() methods

#make a scatter plot of the result
xs = transformed[:, 0]
ys = transformed[:, 1]
plot.scatter(xs, ys, c=categories)
plot.show()

# %% [markdown]
# If only one big cluster is seen in this manner, one could ideally use a another column to examine distribution based on that column.

# %% [markdown]
# Example ![image.png](attachment:image.png)

# %%
import seaborn as sns
import maptplotlib.pyplot as plt

sns.scatterplot(x='xs', y='xy', hue='another_column', data=df)
plt.show()

# %% [markdown]
# Example ![image.png](attachment:image.png)

# %% [markdown]
# The distribution now can be seen better by this variable whereby the bmi_class for overweight extends to the right of the x-axis and underweight towards the left.

# %% [markdown]
# Example 2 ![image.png](attachment:image.png)

# %% [markdown]
# In this case, we can see the distribution follows and up-down variance, with the majority as "normal" sitting in the middle.

# %% [markdown]
# #### t-SNE learning rate

# %% [markdown]
# - Makes t-SNE more complicated than other learning models
# - this is why clustering modeling should be wisely choosen based on the dataset
